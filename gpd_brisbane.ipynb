# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file("brisbane/Flood___Awareness___Flood_Risk_Overall.shp")
gdf
# Out:
#        OBJECTID FLOOD_RISK              FLOOD_TYPE    SHAPE_Leng  \
# 0             1       High  Creek River Storm Tide    115.763373
# 1             2       High  Creek River Storm Tide    454.871655
# 2             3       High  Creek River Storm Tide    144.000000
# 3             4       High  Creek River Storm Tide    193.892540
# 4             5       High  Creek River Storm Tide    134.964673
# ...         ...        ...                     ...           ...
# 73133     73134   Very Low  Creek River Storm Tide      3.227248
# 73134     73135   Very Low  Creek River Storm Tide      0.851573
# 73135     73136   Very Low  Creek River Storm Tide    111.767944
# 73136     73137   Very Low  Creek River Storm Tide  30363.097738
# 73137     73138   Very Low  Creek River Storm Tide  22246.262157
#
#           SHAPE_Area                                           geometry
# 0         368.799338  POLYGON ((499827.500 6941076.664, 499832.500 6...
# ...

# %%
gdf.plot()
plt.show()
