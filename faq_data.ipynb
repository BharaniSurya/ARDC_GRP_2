# %%
import pandas as pd

data = [
    ("What is the purpose of having an Emergency Plan?", "Having an Emergency Plan is crucial for preparing for, surviving, and coping with emergencies."),
    ("How should all household members be involved in disaster preparations?", "All household members should be involved in disaster preparations to ensure that everyone understands the risks and the appropriate actions required in an emergency."),
    ("Why is it important to practice your Emergency Plan regularly?", "Practicing your Emergency Plan regularly is important to make sure that all household members know what to do if an emergency occurs."),
    ("What are the four key steps to help create your Emergency Plan?", "The four key steps to create your Emergency Plan are: Research hazards and disaster management in your community, Discuss possible scenarios and responses with your household, Record important details on your Emergency Plan, Ensure everyone in your household is prepared."),
    ("How can you research hazards and disaster management arrangements in your community?", "You can research hazards and disaster management by identifying potential hazards, checking local Disaster Management Plans, and inquiring with your local library, local council, workplace, school, and childcare providers."),
    ("What should you inquire about at your local council regarding emergency plans?", "Inquire about local warning systems, evacuation processes, nominated evacuation routes, and any information or support required by your household."),
    ("Why is it important to know local warning systems and evacuation processes?", "Knowing local warning systems and evacuation processes is vital to respond effectively in an emergency and ensure your safety."),
    ("What can you ask your workplace, school, and childcare providers about?", "Ask about their emergency and evacuation plans and check if they need details of your household emergency contacts."),
    ("Why should you record contact details of local support agencies on your Emergency Plan?", "Recording contact details of local support agencies on your Emergency Plan ensures you can reach out for assistance during an emergency."),
    ("What should you do if your household needs support to evacuate?", "If your household needs support to evacuate, find out what assistance is available from local council and support agencies."),
    ("What should you become familiar with regarding weather warnings?", "Become familiar with weather warnings issued by the Bureau of Meteorology website and phone services to stay informed about potential hazards."),
    ("What types of scenarios should you discuss with your household?", "Discuss potential scenarios for each hazard and what actions you would take in the event of each emergency."),
    ("Why is it important to discuss where you might be during an emergency?", "Discussing where you might be during an emergency helps you plan how to stay in touch and where to meet."),
    ("What is the Standard Emergency Warning Signal (SEWS), and why is it important to know?", "SEWS is a standard warning signal used during emergencies. Knowing SEWS is crucial to understanding what to do when this warning is issued."),
    ("What should you decide if you have to prepare for evacuation?", "If you need to prepare for evacuation, decide where to go if you can't return home or need to leave your home."),
    ("Why is it essential to nominate two meeting places in case of an emergency?", "Nominating two meeting places ensures that you have options for where to gather your household members."),
    ("How can you prepare to keep in touch during an emergency?", "Prepare by nominating two family members or friends who do not live with you to be household emergency contacts. Make sure everyone knows how to contact them."),
    ("Why should you discuss the medical conditions of household members?", "Discussing medical conditions helps you include essential medications and dosages in your Emergency Kit and plan for any special needs."),
    ("What preparations are needed for your pets during an emergency?", "Consider what provisions are required for your pets, including their descriptions, photos, veterinarian contact details, and medications."),
    ("What important details should you record on your Emergency Plan?", "You should record emergency and related phone numbers, including Triple Zero (000), medical services, local council, electricity and other service providers, insurance providers, and relatives and friends. Include all household members' mobile phones, work, school, childcare providers, friends, neighbors, and your household emergency contacts. Document details of your two nominated meeting places."),
    ("Why is it important to ensure everyone in your household is prepared?", "Ensuring that everyone in your household is prepared is vital for the overall safety and well-being of your household during an emergency."),
    ("How can you prepare an Emergency Kit and where should you store it?", "Prepare an Emergency Kit and store it in a safe, accessible place. Review and practice your Emergency Plan regularly."),
    ("How can you teach children when and how to call Triple Zero (000) during an emergency?", "Teach children how and when to call Triple Zero (000) in an emergency and remind them to use 112 from mobile phones. Only call Triple Zero (000) if the emergency is life-threatening, critical, or serious."),
    ("Why is it important to have household members with current First Aid certification?", "Household members with current First Aid certification can provide essential medical assistance during an emergency. Include a fully stocked First Aid Kit in your Emergency Kit."),
    ("What should you do if you want to tune into emergency warnings?", "To stay informed, tune into emergency warnings through local ABC radio stations, the Bureau of Meteorology website, and telephone weather services for local warnings."),
    ("Why is it a good idea to create wallet emergency cards for all household members?", "Creating wallet emergency cards for household members ensures they have important information readily available when activating your Emergency Plan."),
    ("What information should you provide on wallet emergency cards?", "Include emergency contact numbers, medical conditions, essential medications, and dosage details on wallet emergency cards."),
    ("How can you ensure everyone knows where and when to turn off the main power, water, and gas supply?", "Educate household members about turning off the main power, water, and gas supply, especially in case of evacuation."),
    ("How can you make your Emergency Plan easily accessible to everyone in your household?", "Display your Emergency Plan on the fridge or household notice board, provide copies to household members, friends, family, and neighbors, and keep a copy in your Emergency Kit."),
    ("What community emergency services organization can you join to help your community prepare for and respond to natural disasters?", "Consider joining a community emergency services organization such as the State Emergency Service (SES) to learn more and contribute to your community's disaster preparedness."),
    ("What is the importance of developing an evacuation plan?", "Developing an evacuation plan is crucial because it can save time and reduce stress in the event of an emergency."),
    ("Why is it essential to research hazards and disaster management arrangements in your community?", "Researching hazards and disaster management arrangements helps you understand potential risks and make informed decisions during an emergency."),
    ("What should you check regarding Disaster Management Plans in your community?", "Check if there is information available on Disaster Management Plans for potential hazards in your community."),
    ("Where can you find information and plans related to disaster management in your community?", "You can check with your local library and local council for information and plans on disaster management."),
    ("What should you inquire about at your local council regarding evacuation?", "Inquire about local warning systems, evacuation processes, and nominated evacuation routes with your local council."),
    ("Why should you find out if you live in a flood-prone area or evacuation zone?", "It's important to determine if you live in a flood-prone area or evacuation zone to make arrangements for evacuation, such as staying with friends on higher ground."),
    ("What information should you seek at your workplace, school, and childcare providers?", "Ask about emergency and evacuation plans at your workplace, school, and childcare providers. Check if they need details of your household emergency contacts."),
    ("Why is it important to ask about local support?", "Asking about local support helps you identify available resources and assistance during an evacuation."),
    ("What should you do if your household will need support to evacuate?", "Find out what assistance is available if your household will need support to evacuate."),
    ("How can you become familiar with weather warnings?", "Become familiar with weather warnings issued by the Bureau of Meteorology website and phone services to stay informed about potential hazards."),
    ("What should you discuss with your household members regarding hazards and emergencies?", "Discuss each hazard and potential scenarios, including what actions to take in the event of each emergency."),
    ("Why is it important to discuss where you might be during an emergency?", "Discussing where you might be during an emergency helps you plan how to stay in touch and where to meet."),
    ("What is the Standard Emergency Warning Signal (SEWS), and why is it important to know about it?", "SEWS is a standard warning signal used during emergencies. Knowing SEWS is crucial for understanding how to respond when this warning is issued."),
    ("What should you decide regarding evacuation during an emergency?", "Decide where to go if you are unable to return home or if you have to leave your home as part of your evacuation plan."),
    ("Why is it essential to nominate two meeting places in case of an emergency?", "Nominating two meeting places provides options for where to gather your household members during an emergency."),
    ("How can you prepare to keep in touch during an emergency?", "Prepare by nominating two family members or friends who do not live with you as household emergency contacts. Make sure everyone knows how to contact these people."),
    ("What should you discuss regarding medical conditions of household members?", "Discuss the medical conditions of household members and include essential medications and dosages in your Emergency Kit."),
    ("What preparations are needed for your pets during an evacuation?", "Consider what provisions are required for your pets, including their descriptions, photos, veterinarian contact details, and medications."),
    ("What is the checklist for evacuation?", "The checklist for evacuation includes ensuring official advice has been given to evacuate, knowing your evacuation point, confirming the evacuation point is secure, knowing the preferred evacuation route, having a vehicle full of fuel, packing your Emergency Plan, packing your Emergency Kit, packing your Evacuation Kit, having essential medications for your family, packing important documents and valuables, turning off all the power, gas, and water mains to your home, ensuring your pets are safe and secure, securing and locking your home, packing emergency water supplies, checking on elderly or disabled neighbors, and identifying options for evacuation if you are visiting or on holiday in Queensland or interstate without family or friends to shelter with."),
    ("Why is it important to secure and lock your home before evacuating?", "Securing and locking your home is important to protect it and its contents while you are away during an evacuation."),
    ("What should you do if you are visiting or on holiday in Queensland or interstate and do not have family or friends to shelter with?", "If you are visiting or on holiday in Queensland or interstate and do not have family or friends to shelter with, contact your accommodations manager to identify options for evacuation."),
    ("Why should you have an Evacuation Kit prepared?", "Having an Evacuation Kit prepared is important because it ensures you have essential items and supplies readily available when you need to evacuate."),
    ("What essential items should you include in your Evacuation Kit?", "Your Evacuation Kit should include items such as non-perishable food, water, a first-aid kit, essential medications, important documents, a flashlight, batteries, a multi-tool, clothing, and personal hygiene items."),
    ("How can you ensure that everyone in your household knows about your evacuation plan?", "Ensure everyone in your household knows about your evacuation plan by discussing it regularly, practicing evacuation drills, and having a copy of the plan accessible to all."),
    ("What should you consider regarding children and the elderly in your household during an evacuation?", "Consider the specific needs of children and the elderly in your household, including necessary supplies, medications, and arrangements for their comfort and safety during an evacuation."),
    ("What's the importance of knowing the locations of evacuation centers in your community?", "Knowing the locations of evacuation centers is crucial for planning your evacuation and ensuring that you have a safe destination to go to."),
    ("How can you get information about evacuation centers in your area?", "You can get information about evacuation centers from local authorities, emergency management agencies, or by checking with your local council."),
    ("What is the purpose of having a designated meeting place for your household during an evacuation?", "Having a designated meeting place ensures that all members of your household know where to gather in case of separation during an evacuation."),
    ("Why is it important to have a communication plan for your household during an evacuation?", "Having a communication plan ensures that all household members know how to contact each other and where to meet during an evacuation."),
    ("How can you teach your household members about the Standard Emergency Warning Signal (SEWS)?", "You can teach your household members about SEWS by providing information and discussing its significance in emergency situations."),
    ("What steps should you take to prepare your pets for evacuation?", "To prepare your pets for evacuation, ensure that you have carriers or crates, food, water, medications, and identification for your pets ready to go."),
    ("What should you do if official advice is given to evacuate?", "If official advice is given to evacuate, follow the advice and execute your evacuation plan immediately."),
    ("Why is it essential to know your evacuation point and the preferred evacuation route?", "Knowing your evacuation point and preferred route is critical for a smooth and safe evacuation."),
    ("Why should you ensure that your vehicle is full of fuel before an evacuation?", "Ensuring that your vehicle has a full tank of fuel is important because it allows you to travel a longer distance without the need for refueling during the evacuation."),
    ("What is the purpose of packing your Emergency Plan during an evacuation?", "Packing your Emergency Plan ensures that you have all essential information and contacts readily available in case you need to refer to it during an evacuation."),
    ("Why should you pack your Emergency Kit when evacuating?", "Packing your Emergency Kit is essential as it contains necessary supplies, such as food, water, first-aid items, and tools, to support your household during an evacuation."),
    ("What is the importance of having an Evacuation Kit during the evacuation process?", "Having an Evacuation Kit is important because it provides you with essential items and supplies to sustain your household during the evacuation."),
    ("What should you ensure regarding essential medications for your family during an evacuation?", "Ensure that you have essential medications for your family readily available in your Evacuation Kit to address any medical needs during the evacuation."),
    ("Why is it important to include important documents and valuables in your evacuation preparations?", "Including important documents and valuables in your evacuation preparations ensures that you have access to critical information and assets in case of an emergency."),
    ("What precautions should you take when turning off the power, gas, and water mains to your home before evacuating?", "When turning off the power, gas, and water mains to your home, ensure that it is done safely to prevent hazards while you are away."),
    ("How can you ensure the safety of your pets during an evacuation?", "To ensure the safety of your pets during an evacuation, make sure they are secure in carriers or crates and have sufficient food, water, and identification."),
    ("Why should you secure and lock your home before leaving for an evacuation?", "Securing and locking your home before leaving for an evacuation is important to protect your property and belongings from theft or damage."),
    ("What should you do if you are visiting or on holiday in Queensland or interstate and do not have family or friends to shelter with during an emergency?", "If you are visiting or on holiday in Queensland or interstate and do not have family or friends to shelter with, contact your accommodations manager to explore options for evacuation."),
    ("What is the purpose of having an Emergency Kit?", "Having an Emergency Kit is crucial to prepare for, survive, and cope with emergencies."),
    ("Why do all household members need to know where the Emergency Kit is kept?", "All household members need to know where the Emergency Kit is kept for easy access and use during emergencies."),
    ("Why is it important to check and update the contents of your Emergency Kit regularly?", "Checking and updating the contents of your Emergency Kit regularly ensures that everything is in working order and has not expired, maintaining its effectiveness."),
    ("What should you discuss with all household members regarding the Emergency Kit?", "Discuss the contents and use of the Emergency Kit with all household members to ensure everyone knows what to do in an emergency."),
    ("What items should be kept in your Emergency Kit at all times for food and water?", "Your Emergency Kit at all times should include a range of non-perishable food items and bottled water."),
    ("What medical and sanitation items should be part of your Emergency Kit?", "Your Emergency Kit should include a First Aid Kit and manual, essential medications, prescriptions, dosage information, toilet paper, toothbrush, toothpaste, soap, shampoo, and personal hygiene items."),
    ("What kind of light sources should you have in your Emergency Kit?", "Include a flashlight or torch with extra batteries and a battery-powered lantern in your Emergency Kit for lighting."),
    ("What communication items are necessary in your Emergency Kit?", "Your Emergency Kit should have a battery-powered radio with extra batteries and prepaid phone cards and coins for phone calls."),
    ("What clothing and footwear items should be included in your Emergency Kit?", "Your Emergency Kit should contain warm jumpers, waterproof jackets, hats, and gloves for everyone, as well as closed-toed shoes or boots for everyone."),
    ("What tools and supplies are recommended for your Emergency Kit?", "Include a whistle, utility knife, duct or masking tape, plastic garbage bags with ties, safety glasses, and sunglasses in your Emergency Kit."),
    ("What miscellaneous items should you have for infants in your Emergency Kit?", "Include special items for infants such as nappies and formula in your Emergency Kit."),
    ("What should you keep in your Emergency Kit for elderly or people with special needs?", "Ensure you have any special items needed by elderly individuals or those with special needs in your Emergency Kit."),
    ("What are the essential spare items for your house and car to include in your Emergency Kit?", "Add spare house and car keys to your Emergency Kit."),
    ("What should be included in your Emergency Kit for pets and animals?", "Include pet food, water, and other animal needs in your Emergency Kit."),
    ("Why is it recommended to have a diabetes emergency plan in your Emergency Kit?", "Including a diabetes emergency plan in your Emergency Kit is crucial if someone in your household has diabetes."),
    ("What important documents should be part of your Emergency Kit?", "Include original or certified copies of important documents in your Emergency Kit. These documents should be kept in sealed plastic bags."),
    ("Why should you scan copies of important documents and save them on a USB memory stick or CD?", "Scanning copies of important documents and saving them on a USB memory stick or CD ensures that you have electronic backups available in your Emergency Kit."),
    ("What insurance papers should you have in your Emergency Kit?", "Include insurance papers for your house and contents, cars, and valuable items in your Emergency Kit."),
    ("What inventory of valuable household goods should be part of your Emergency Kit?", "Maintain an inventory of valuable household goods in your Emergency Kit."),
    ("What documents related to wills and life insurance should you include in your Emergency Kit?", "Store wills and life insurance documents in your Emergency Kit."),
    ("What house-related documents are important for your Emergency Kit?", "Include house deeds and mortgage documents in your Emergency Kit."),
    ("What personal identification and certification documents are essential for your Emergency Kit?", "Store birth and marriage certificates, passports and visa details, stocks and bonds in your Emergency Kit."),
    ("What medical and health records should be part of your Emergency Kit?", "Include Medicare cards, pension cards, immunization records, and any other relevant medical records in your Emergency Kit."),
    ("Why should you have bank account and credit card details in your Emergency Kit?", "Including bank account and credit card details in your Emergency Kit is essential for financial access during an emergency."),
    ("What computer-related item should have a backup copy in your Emergency Kit?", "Create a backup copy of important computer files and store them in your Emergency Kit."),
    ("What should be included in your Household Emergency Plan with emergency contact numbers?", "Your Household Emergency Plan should contain emergency contact numbers for various agencies and individuals."),
    ("What is the purpose of having an Emergency Kit?", "Having an Emergency Kit is crucial to prepare for, survive, and cope with emergencies."),
    ("Why do all household members need to know where the Emergency Kit is kept?", "All household members need to know where the Emergency Kit is kept for easy access and use during emergencies."),
    ("Why is it important to check and update the contents of your Emergency Kit regularly?", "Checking and updating the contents of your Emergency Kit regularly ensures that everything is in working order and has not expired, maintaining its effectiveness."),
    ("What should you discuss with all household members regarding the Emergency Kit?", "Discuss the contents and use of the Emergency Kit with all household members to ensure everyone knows what to do in an emergency."),
    ("What items should be kept in your Emergency Kit at all times for food and water?", "Your Emergency Kit at all times should include a range of non-perishable food items and bottled water."),
    ("What medical and sanitation items should be part of your Emergency Kit?", "Your Emergency Kit should include a First Aid Kit and manual, essential medications, prescriptions, dosage information, toilet paper, toothbrush, toothpaste, soap, shampoo, and personal hygiene items."),
    ("What kind of light sources should you have in your Emergency Kit?", "Include a flashlight or torch with extra batteries and a battery-powered lantern in your Emergency Kit for lighting."),
    ("What communication items are necessary in your Emergency Kit?", "Your Emergency Kit should have a battery-powered radio with extra batteries and prepaid phone cards and coins for phone calls."),
    ("What clothing and footwear items should be included in your Emergency Kit?", "Your Emergency Kit should contain warm jumpers, waterproof jackets, hats, and gloves for everyone, as well as closed-toed shoes or boots for everyone."),
    ("What tools and supplies are recommended for your Emergency Kit?", "Include a whistle, utility knife, duct or masking tape, plastic garbage bags with ties, safety glasses, and sunglasses in your Emergency Kit."),
    ("What miscellaneous items should you have for infants in your Emergency Kit?", "Include special items for infants such as nappies and formula in your Emergency Kit."),
    ("What should you keep in your Emergency Kit for elderly or people with special needs?", "Ensure you have any special items needed by elderly individuals or those with special needs in your Emergency Kit."),
    ("What are the essential spare items for your house and car to include in your Emergency Kit?", "Add spare house and car keys to your Emergency Kit."),
    ("What should be included in your Emergency Kit for pets and animals?", "Include pet food, water, and other animal needs in your Emergency Kit."),
    ("Why is it recommended to have a diabetes emergency plan in your Emergency Kit?", "Including a diabetes emergency plan in your Emergency Kit is crucial if someone in your household has diabetes."),
    ("What important documents should be part of your Emergency Kit?", "Include original or certified copies of important documents in your Emergency Kit. These documents should be kept in sealed plastic bags."),
    ("Why should you scan copies of important documents and save them on a USB memory stick or CD?", "Scanning copies of important documents and saving them on a USB memory stick or CD ensures that you have electronic backups available in your Emergency Kit."),
    ("What insurance papers should you have in your Emergency Kit?", "Include insurance papers for your house and contents, cars, and valuable items in your Emergency Kit."),
    ("What inventory of valuable household goods should be part of your Emergency Kit?", "Maintain an inventory of valuable household goods in your Emergency Kit."),
    ("What documents related to wills and life insurance should you include in your Emergency Kit?", "Store wills and life insurance documents in your Emergency Kit."),
    ("What house-related documents are important for your Emergency Kit?", "Include house deeds and mortgage documents in your Emergency Kit."),
    ("What personal identification and certification documents are essential for your Emergency Kit?", "Store birth and marriage certificates, passports and visa details, stocks and bonds in your Emergency Kit."),
    ("What medical and health records should be part of your Emergency Kit?", "Include Medicare cards, pension cards, immunization records, and any other relevant medical records in your Emergency Kit."),
    ("Why should you have bank account and credit card details in your Emergency Kit?", "Including bank account and credit card details in your Emergency Kit is essential for financial access during an emergency."),
    ("What computer-related item should have a backup copy in your Emergency Kit?", "Create a backup copy of important computer files and store them in your Emergency Kit."),
    ("What should be included in your Household Emergency Plan with emergency contact numbers?", "Your Household Emergency Plan should contain emergency contact numbers for various agencies and individuals."),
    ("Why are warnings from Emergency Services important for community safety?", "Warnings from Emergency Services are important for community safety during severe weather and emergencies."),
    ("What actions may you be directed to take when warnings are issued?", "When warnings are issued, you may be directed to finalize preparations, secure items around your home, activate your Emergency Plan, shelter in place, or commence evacuation to a predetermined safer location."),
    ("Why is it important to act immediately on the information provided in warnings?", "It's crucial to act immediately on the information provided in warnings because they are urgent and require prompt action."),
    ("How can you tune in to get weather and warning updates?", "Tune your battery-powered radio to your local station for weather and warning updates. Turn your television to your local station to watch and listen for warning updates."),
    ("Where can you find weather updates and warning information online?", "You can find weather updates and warning information on the Bureau of Meteorology website for weather updates and Queensland Disaster Management Services website for information on preparing, Emergency Alerts, and current information on disaster events."),
    ("What is the Standard Emergency Warning Signal (SEWS), and why should you listen out for it?", "SEWS is a wailing siren sound used for serious emergency events. You should listen out for it because it precedes important warning information."),
    ("How can you receive emergency alerts via landline and mobile phones?", "Emergency Alert can send voice alerts via landline telephones based on location and test alerts to mobile phones based on billing address. You cannot opt out of receiving emergency alerts."),
    ("What should you do when you receive an Emergency Alert?", "When you receive an Emergency Alert, listen carefully to the advice provided and act immediately, following the directions given."),
    ("Why should you check on neighbors and friends who may need special assistance when warnings are issued?", "Checking on neighbors and friends who may need special assistance is important to ensure their safety and well-being during emergencies."),
    ("When should you activate your Household Emergency Plan?", "You should activate your Household Emergency Plan when directed by warnings or when you believe it's necessary to ensure safety."),
    ("What should you locate and collect when you receive a warning?", "When you receive a warning, locate and collect your Emergency Kit to ensure you have necessary supplies and essentials."),
    ("What is the purpose of the Standard Emergency Warning Signal (SEWS)?", "SEWS is used as a signal to alert the public to major emergencies and to signify the importance of the information that follows."),
    ("Why is it essential to act immediately when SEWS is heard?", "Acting immediately when SEWS is heard is essential because it indicates a major emergency, and swift action may be necessary to protect lives and property."),
    ("Where can you find more information on various weather warnings in Queensland?", "You can find more information on weather warnings in Queensland by contacting Queensland Tropical Cyclone Warnings, Queensland Land Weather and Flood Warnings, Queensland Coastal Marine Warnings, or Queensland General Warnings."),
    ("Why is getting to know your neighbors important in preparing your household for emergencies?", "Getting to know your neighbors is important because neighbors can help each other in various ways during emergencies, and building a community network is crucial."),
    ("Who are considered 'neighbors' in this context?", "Neighbors can include people in your street or community, and they are individuals living in proximity to your residence."),
    ("What's the benefit of getting to know your neighbors' needs before an emergency situation occurs?", "Getting to know your neighbors' needs in advance allows you to identify those who may require assistance during emergencies, and you can plan to provide that help."),
    ("What are some examples of people who may need assistance during emergencies?", "Examples of individuals who may need assistance include older people living alone, those with physical or sensory disabilities, people with chronic illnesses or mental health conditions, single parents with young children, large families, and newcomers like tourists, refugees, or immigrants."),
    ("How can you identify neighbors who may need assistance?", "You can talk to your neighbors to identify those who may need assistance, but it's important to respect their privacy as some people value it."),
    ("What kind of special skills might some neighbors possess that could be valuable during emergencies?", "Some neighbors may have special skills, such as medical, technical, or trade skills, that can be valuable during emergencies."),
    ("What should you plan for regarding your neighborhood's response after a disaster?", "You should plan how the neighborhood could work together after a disaster, which includes organizing and coordinating efforts to help each other."),
    ("What is a community working bee, and why is it useful?", "A community working bee is a gathering where community members come together to help each other. It's useful as it's a great way to get to know your neighbors and build a sense of community."),
    ("Can you provide examples of ways in which you may be able to help your neighbors during emergencies?", "Examples of ways to help your neighbors include assisting those with sensory disabilities in staying informed about weather warnings, helping individuals unable to lift heavy objects, aiding those who need assistance preparing meals or contacting family during power outages, and assisting individuals in securing their property during storms."),
    ("What are some specific ways you can help your neighbors prepare for an emergency?", "You can help your neighbors by assisting them in preparing a household emergency plan, creating an emergency kit, developing an emergency plan for pets or assistance dogs, and identifying and obtaining the resources needed to cope effectively with an emergency."),
    ("In what ways can you assist your neighbors during a disaster?", "You can help your neighbors by moving furniture and valuables out of the way of floodwater, providing information about the situation, aiding in securing properties prior to cyclones or storms, offering a place to shelter during an emergency, and assisting with cleanup efforts after a disaster."),
    ("Why is sitting down with your neighbors and having a chat after an emergency beneficial?", "Sitting down with your neighbors for a chat after an emergency is beneficial because it allows you to share experiences, offer support, and foster a sense of community."),
    ("Why is it important to ensure your pet has access to plenty of food and fresh water during an emergency?", "It's important to ensure your pet's basic needs are met to keep them healthy and safe during emergencies."),
    ("What should you provide for your pet in terms of shelter and bedding during an emergency?", "You should ensure your pet has shelter and comfortable bedding to protect them from the elements."),
    ("Why is proper and easy identification of all animals under your care important?", "Proper identification helps in reuniting lost or separated pets with their owners during or after an emergency."),
    ("What important telephone numbers should you include in your household emergency kit regarding your pets?", "You should include telephone numbers for your veterinarian or animal welfare agency in your household emergency kit."),
    ("What should you never do with your pet during an emergency?", "You should never leave your pet tied-up or chained without shelter and bedding, and you should never leave your pet in a motor vehicle."),
    ("Who is the Pet Emergency Plan for?", "The Pet Emergency Plan is for your household pets."),
    ("What should you do if you have more than two pets or are looking after your neighbors' pets?", "If you have more than two pets or are looking after your neighbors' pets, you should complete a second plan."),
    ("What should you check with your local council and other agencies regarding your pets?", "You should check on possible hazards, local emergency plans, and arrangements for temporary animal shelters during major emergencies or disasters."),
    ("Why may it not be possible to take your pet with you to a temporary evacuation shelter during an emergency?", "It may not be possible to take your pet with you to a temporary evacuation shelter due to safety and space limitations, so you should plan ahead."),
    ("Are trained assistance dogs usually allowed in emergency shelters with their owners?", "In most cases, trained assistance dogs are allowed in emergency shelters with their owners, but proper identification and proof of vaccination may be required."),
    ("What are some general tips to secure your pets inside before an emergency event?", "You should secure your pets inside to prevent them from running away. Using a secure pet carrier, cage, leash, or harness is recommended for transportation to safety."),
    ("What should you ensure remains current for your pets?", "You should ensure that all vaccinations for your pets remain current to protect their health."),
    ("What is an option for your pet during an emergency to be boarded in a safe environment?", "An option for your pet during an emergency is to be boarded in a safe environment away from the emergency zone."),
    ("What information should accompany your pet if they are housed in a temporary foster home?", "If you house your pet in a temporary foster home, ensure their medical and feeding information, food, medicine, and other supplies accompany them."),
    ("Why is proper identification of your pets important during times of disaster?", "Proper identification of your pets is important because during disasters, telephones may not be available, and it is crucial that any registered method includes your current address."),
    ("What can a current photograph of each pet be useful for during emergencies?", "A current photograph of each pet can be useful for identification purposes and to prove your ownership during emergencies."),
    ("What essential items should be included in your pet emergency kit?", "Your pet emergency kit should include medications (for up to two weeks), medical and vaccination records, veterinarian details, sufficient food, a familiar pet blanket or bedding, toys, grooming equipment, a secure pet carrier, leash, or harness, sanitation supplies, and a current photograph of each pet."),
    ("Why is it essential to have a secure pet carrier, leash, or harness in your pet emergency kit?", "Having a secure pet carrier, leash, or harness in your pet emergency kit is important for transporting animals to safety during emergencies."),
    ("Why should you consider your pet's sanitation needs in your pet emergency kit?", "Considering your pet's sanitation needs is essential for maintaining their health. It's also important for your own health and comfort during an emergency."),
    ("What should you include in a bird's emergency kit?", "For birds, you should include special food and water dispensers, and a cover for the cage in their emergency kit."),
    ("What kind of identification methods should be used for your pets in your pet emergency plan?", "Identification methods for your pets should be registered and include your current address."),
    ("What are some specialized agencies you can contact for emergency planning if your companion pets are not cats, dogs, or birds?", "If your companion pets are not cats, dogs, or birds (e.g., aquarium fish, reptiles, small livestock), you may need to make special arrangements and can contact specialized agencies like Queensland Primary Industry and Fisheries (for livestock), the RSPCA, or your local pet shop or animal's veterinarian for advice."),
    ("What is the purpose of the emergency pantry list?", "The emergency pantry list outlines the food needed for 2 people for 7 days without the need for refrigeration, special preparation, or cooking during emergencies."),
    ("What should you do to adapt the pantry list for people with food allergies or specific dietary requirements?", "You should adapt the pantry list to accommodate people with food allergies or specific dietary requirements by making suitable substitutions for the items mentioned."),
    ("What are some examples of grain foods listed in the pantry list?", "Examples of grain foods in the pantry list include breakfast cereals (dry), flatbreads, wholegrain crispbread/dry biscuits, and ready-to-eat rice or noodles."),
    ("How much breakfast cereal (dry) should you have in your emergency pantry for 2 people?", "You should have 850g of dry breakfast cereal, which is equivalent to 28 x 30g single-use bowls or boxes or other combinations mentioned."),
    ("What are some examples of flatbreads (long life, vacuum packed) listed in the pantry list?", "Examples of long life, vacuum-packed flatbreads in the pantry list include pita bread, lavash, tortillas, and wraps."),
    ("How much flatbread should you have in your emergency pantry for 2 people?", "You should have 1100g of flatbread, equivalent to 4 x 260g packs, or other combinations mentioned."),
    ("What are some examples of ready-to-eat rice or noodles in the pantry list?", "Examples of ready-to-eat rice or noodles include those available in 250g packets."),
    ("How much ready-to-eat rice or noodles should you have in your emergency pantry for 2 people?", "You should have 1700g of ready-to-eat rice or noodles, which is equivalent to 8 x 250g packets."),
    ("What types of fruit are listed in the pantry list under the 'Fruit' category?", "The pantry list includes canned fruit in natural juice (e.g., pineapple, peaches, fruit salad, plums, berries, apricots) and dried fruit (e.g., sultanas, apricots, mixed fruit)."),
    ("How much canned fruit in natural juice should you have in your emergency pantry for 2 people?", "You should have 2400g of canned fruit in natural juice, equivalent to 8 x 400/410/420g cans or other containers mentioned."),
    ("How much dried fruit should you have in your emergency pantry for 2 people?", "You should have 200g of dried fruit, which is equivalent to 1 x 210g packet."),
    ("What is listed under 'Fruit juice (100% fruit juice)' in the pantry list?", "The pantry list includes fruit juice (100% fruit juice) available in 250mL tetra packs."),
    ("How much fruit juice (100% fruit juice) should you have in your emergency pantry for 2 people?", "You should have 750mL of fruit juice, equivalent to 3 x 250mL tetra packs."),
    ("What types of vegetables are listed in the pantry list under the 'Vegetables' category?", "The pantry list includes starchy vegetables (e.g., canned potatoes), green vegetables (e.g., canned peas, beans, asparagus), and orange and other vegetables (e.g., canned beetroot, carrots, corn, tomatoes, mushrooms, capsicum, mixed vegetables)."),
    ("How much starchy vegetables should you have in your emergency pantry for 2 people?", "You should have 1050g of starchy vegetables, equivalent to 4 x 410g cans or other combinations mentioned."),
    ("How much green vegetables should you have in your emergency pantry for 2 people?", "You should have 1050g of green vegetables, equivalent to 7 x 220g cans or other combinations mentioned."),
    ("How much orange and other vegetables should you have in your emergency pantry for 2 people?", "You should have 3150g of orange and other vegetables, equivalent to 14 x 420g cans or other combinations mentioned."),
    ("What types of legumes and beans are listed in the pantry list under the 'Legumes and beans' category?", "The pantry list includes canned legumes (e.g., kidney beans, 4-bean mix, chickpeas, lentils) and baked beans."),
    ("How much canned legumes should you have in your emergency pantry for 2 people?", "You should have 1000g of canned legumes, equivalent to 4 x 410g cans or other combinations mentioned."),
    ("How much baked beans should you have in your emergency pantry for 2 people?", "You should have 750g of baked beans, equivalent to 4 x 220g cans."),
    ("How much nuts and/or seeds (unsalted) should you have in your emergency pantry for 2 people?", "You should have 450g of nuts and/or seeds (unsalted), equivalent to 3 x 150g packets."),
    ("What types of milk, yoghurt, and cheese are listed in the pantry list?", "The pantry list includes long-life milk or calcium-fortified soy milk and long-life cheese (e.g., cheese wedges or sticks)."),
    ("How much long-life milk or calcium-fortified soy milk should you have in your emergency pantry for 2 people?", "You should have 5000mL of long-life milk or calcium-fortified soy milk, equivalent to 20 x 250mL tetra packs."),
    ("How much long-life cheese should you have in your emergency pantry for 2 people?", "You should have 400g of long-life cheese, equivalent to 1 x 160g box or 1 x 240g packet."),
    ("What is listed under 'Long life custard' in the pantry list?", "The pantry list includes long-life custard available in 4-pack custard cups."),
    ("How much long-life custard should you have in your emergency pantry for 2 people?", "You should have 800g of long-life custard, equivalent to 2 x 4-pack custard cups."),
    ("What types of canned meat, poultry, fish, and alternatives are listed in the pantry list?", "The pantry list includes canned meat and/or poultry or alternatives (e.g., braised steak, canned chicken, canned ham, nut meat) and canned fish (e.g., tuna, salmon, sardines)."),
    ("How much canned meat and/or poultry or alternatives should you have in your emergency pantry for 2 people?", "You should have 900g of canned meat and/or poultry or alternatives, equivalent to 12 x 85g cans (chicken) or other combinations mentioned."),
    ("How much canned fish should you have in your emergency pantry for 2 people?", "You should have 1600g of canned fish, equivalent to 8 x 185/210g cans."),
    ("What is listed under 'Unsaturated oil' in the pantry list?", "The pantry list includes unsaturated oil, e.g., olive oil, available in a 375mL bottle."),
    ("How much unsaturated oil should you have in your emergency pantry for 2 people?", "You should have 280g of unsaturated oil, equivalent to 1 x 375mL bottle."),
    ("Are snack foods listed as an essential item in the pantry list?", "Snack foods are listed as optional in the pantry list. Some examples of snack foods include dried fruits, nuts, seeds, crackers or biscuits, and muesli bars."),
    ("What is listed under 'Bottled water for drinking and food preparation' in the pantry list?", "The pantry list includes bottled water for drinking and food preparation, totaling 42 liters, which is equivalent to 21 x 2-liter bottles."),
    ("What equipment is included in the emergency pantry list?", "The equipment includes plastic plates, bowls, cups, cutlery, and utensils, as well as a can opener and hand sanitizer (water-free)."),
    ("How much hand sanitizer (water-free) should you have in your emergency pantry for 2 people?", "You should have 2 tubes/bottles of hand sanitizer (water-free), equivalent to 2 x 200mL bottles."),
        ("What are the nutritional needs of babies aged 0–6 months during an emergency?", 
     "Babies aged 0–6 months rely on breast milk. Offer breastfeeds more often during hot weather. Water or other drinks are not needed unless recommended by a doctor."),
    ("What are the nutritional needs of babies aged 6–12 months during an emergency?", 
     "Babies aged 6–12 months need food and fluids in addition to breast milk. During hot weather, you can give small amounts of cooled boiled water after or in between breastmilk feeds."),
    ("What are the nutritional needs of babies over 12 months during an emergency?", 
     "Babies over 12 months need solid foods and drinks, continue breastfeeding, or give full cream milk via a cup. During hot weather, give cooled boiled water after or in between meals."),
    ("What does the pantry list for breastfeeding during an emergency cover?", 
     "The pantry list covers the food and equipment required for 1 baby if water and electricity have been interrupted for 3 days, based on the national infant feeding guidelines."),
    ("Why is it important to rely on breast milk for babies aged 0–6 months during an emergency?", 
     "Breast milk is the primary source of nutrition for babies aged 0–6 months and provides essential nutrients and hydration. It is sufficient, and additional water or drinks are not needed unless advised by a doctor."),
    ("What should you do if you have a baby aged 0–6 months during an emergency and water and electricity are interrupted?", 
     "If you have a baby aged 0–6 months during an emergency with interrupted water and electricity, continue to offer breastfeeds more frequently, especially in hot weather. Avoid giving water or other drinks unless recommended by a doctor."),
    ("When should you consider giving small amounts of cooled boiled water to a baby aged 6–12 months during an emergency?", 
     "For babies aged 6–12 months during an emergency, you can consider giving small amounts of cooled boiled water after or in between breastmilk feeds, especially in hot weather."),
    ("What is the recommended approach for babies over 12 months during an emergency?", 
     "For babies over 12 months during an emergency, they need solid foods and drinks. You can continue breastfeeding or give full cream milk via a cup. In hot weather, provide cooled boiled water after or in between meals."),
    ("How should you adapt the pantry list for babies with food intolerances and allergies?", 
     "You should adapt the pantry list for babies with food intolerances and allergies by selecting suitable food items that meet their specific dietary requirements."),
    ("What are some considerations for breastfeeding mothers during an emergency?", 
     "Breastfeeding mothers should stay well-hydrated and nourished. It's essential for mothers to take care of their own health to continue breastfeeding effectively during an emergency."),
    ("Why is breastfeeding particularly important during emergencies?", 
     "Breastfeeding is crucial during emergencies because breast milk is a safe and readily available source of nutrition and hydration for infants. It does not require preparation, clean water, or electricity, making it ideal during disruptions."),
    ("How can breastfeeding mothers ensure they have enough milk supply during an emergency?", 
     "To ensure an adequate milk supply during an emergency, breastfeeding mothers should continue breastfeeding on-demand and stay well-hydrated and nourished. Reducing stress and getting enough rest can also support milk production."),
    ("What should breastfeeding mothers do if they experience stress or anxiety during an emergency?", 
     "Breastfeeding mothers should seek support from family, friends, or healthcare professionals if they experience stress or anxiety during an emergency. Reducing stress is essential for successful breastfeeding."),
    ("Are there any specific foods that breastfeeding mothers should include in their pantry during an emergency?", 
     "Breastfeeding mothers should include nutritious and non-perishable foods in their pantry, such as whole grains, dried fruits, nuts, and foods high in protein. These foods can help maintain their energy and milk production."),
    ("How can breastfeeding mothers ensure their own safety and well-being during an emergency?", 
     "Breastfeeding mothers should prioritize their safety and well-being by following emergency guidelines, staying informed, and having an emergency plan in place. Having support from family and friends is also crucial."),
    ("What role does community support play in assisting breastfeeding mothers during emergencies?", 
     "Community support is vital in assisting breastfeeding mothers during emergencies. Communities can provide resources, information, and support networks to help mothers continue breastfeeding even in challenging situations."),
    ("Why can accessing medicine during a disaster be challenging?", 
     "Natural disasters can disrupt access to medicines due to various factors, including damage to infrastructure, transportation issues, and supply chain disruptions."),
    ("What should you do if you need to take medicine with food or water during a disaster?", 
     "During a disaster, ensure you use safe drinking water and follow food safety guidelines if your medication requires food or water for administration."),
    ("Is a prescription required to obtain Pharmaceutical Benefit Scheme (PBS) medicines in an emergency?", 
     "In an emergency, you can obtain PBS medicines without a prescription. Your usual pharmacy may provide a three-day supply without a prescription or contact your doctor for a verbal prescription. Co-payments may apply."),
    ("Do the co-payments for PBS medicines during an emergency count towards the PBS Safety Net?", 
     "The co-payments for PBS medicines during an emergency supply do not count towards the PBS Safety Net."),
    ("What should you do if you can't reach your usual pharmacy during a disaster?", 
     "If you can't reach your usual pharmacy, try visiting another community pharmacy if it is safe. In some cases, your GP's prescriptions can be filled by Queensland Health public hospital pharmacies, but they may not stock the full range of medicines."),
    ("How can you access medicines if you can't get to your usual pharmacy?", 
     "In an emergency, you may be able to negotiate a credit arrangement with a pharmacy or public hospital pharmacy if you can't access your money. They may dispense medicines without collecting co-payments immediately."),
    ("What should you do if you don't have your Medicare or concession card during a disaster?", 
     "Your pharmacy or public hospital can contact Medicare to confirm your eligibility to receive PBS medicines and apply the concessional patient co-payment rate even if you don't have your card. You'll still need to pay co-payments."),
    ("Can you replace lost medicine without a prescription during a disaster?", 
     "If you've lost your medicine but still have your prescription, your pharmacy can dispense a new supply in an emergency, even if the prescription was last filled less than 20 days ago. Co-payments don't count towards the PBS Safety Net."),
    ("What can be done if your medication requires special authority and you need a replacement during a disaster?", 
     "If your medication requires special authority, your doctor can call Medicare for authority to issue another prescription, allowing the pharmacist to dispense the medicine again, even if it's 'too soon.' Co-payments may apply."),
    ("Who should you contact for urgent assistance with obtaining medicine during a disaster?", 
     "For urgent assistance with obtaining medicine during a disaster, contact the State Emergency Services (SES) at 132 500 to arrange evacuation or alternative supply options."),
    ("What is the Pharmaceutical Benefit Scheme (PBS)?", 
     "The PBS is a government program that provides affordable access to necessary prescription medicines for Australian residents. It aims to reduce the cost of prescription medications for individuals."),
    ("What is a concessional patient co-payment rate for medicines?", 
     "A concessional patient co-payment rate is a reduced fee for prescription medicines available to individuals with a valid concession card, such as a healthcare or pension card."),
    ("How can you access your Medicare or concession card details during an emergency if you don't have the physical card?", 
     "Your pharmacy or public hospital can contact Medicare to retrieve your card details by phone. This allows you to benefit from concessional patient co-payment rates."),
    ("Why is it important to have access to medicines during a disaster?", 
     "Access to necessary medicines is crucial during a disaster, as individuals may rely on these medications to manage chronic conditions or respond to acute health needs."),
    ("What should you do if you need to evacuate during a disaster and require medication?", 
     "If you need to evacuate during a disaster and require medication, contact the State Emergency Services (SES) at 132 500 to arrange for evacuation and discuss your medication needs."),
     ("What are the common elements produced by cyclones and severe storms?", 
     "Cyclones and severe storms can produce hail, flooding rains, lightning, winds greater than 200km/h, and storm surge."),
    ("When is storm season in your region, and why is it important to stay informed during this time?", 
     "Storm season typically occurs from November to April. It's crucial to stay informed during this time to protect your family and property from potential severe weather events."),
    ("What preparations should you make for your home before a cyclone or severe storm occurs?", 
     "Before a cyclone or severe storm, you should prepare your home by securing outdoor items, sheltering animals, moving wheelie bins inside, and taking various other protective measures."),
    ("What should you do when you receive a severe storm or cyclone warning?", 
     "When you receive a severe storm or cyclone warning, stay tuned for further information, contact family and neighbors to ensure their awareness, and take various precautions like securing outdoor furniture and vehicles."),
    ("How can you secure windows in preparation for a cyclone?", 
     "You can secure windows by closing shutters (if available) and taping other windows in a criss-crossing pattern using strong packing tape. It's important to close curtains or blinds as well."),
    ("What should you do with your boat when a cyclone or severe storm is approaching?", 
     "When a cyclone or severe storm is approaching, you should secure your boat to prevent it from being damaged by strong winds."),
    ("Is it advisable to evacuate during a cyclone or severe storm, and under what circumstances?", 
     "Whether to evacuate or stay at home depends on your location and specific circumstances. If your home is in a storm tide evacuation area, evacuating to secure accommodation further inland may be necessary. It's important to consider special medical needs and have an evacuation plan and kit ready."),
    ("What should you consider when deciding whether to use a cyclone shelter?", 
     "Cyclone shelters should be considered only as a last resort. They have basic facilities and are intended for short-term shelter. The decision to use a cyclone shelter is typically made by your local council and will be announced on local radio and other media."),
    ("What precautions should you take while at home during a severe storm or cyclone?", 
     "While at home during a severe storm or cyclone, you should stay tuned in to warnings, activate your emergency plan, stay indoors, shelter away from windows and doors, avoid using landline phones and taps, and have a plan for seeking the strongest part of your home if necessary."),
    ("What steps should you take if you are outdoors during a severe storm or cyclone?", 
     "If you are outdoors during a severe storm or cyclone, seek solid enclosed shelter. If driving, stop clear of trees, power lines, and streams."),
    ("What precautions should you take in the immediate aftermath of a cyclone?", 
     "After a cyclone, it's essential to remain indoors until authorities declare it safe to go outside. Use recommended routes to return to your home, avoid sightseeing, check on neighbors if needed, be cautious with electrical appliances that have been wet, purify your water, and stay away from damaged powerlines, fallen trees, and floodwater."),
        ("How can you stay informed about cyclone and severe storm warnings?", 
     "You can stay informed by tuning in to local radio and following weather forecasts from official sources."),
    ("What should you do if you have pets during a severe storm or cyclone?", 
     "If you have pets, you should shelter and secure them, ensuring their safety during the storm."),
    ("Why is it important to secure outdoor furniture and loose items during a storm or cyclone?", 
     "Securing outdoor furniture and loose items prevents them from becoming dangerous projectiles in high winds."),
    ("Can you use electrical appliances during a severe storm or cyclone?", 
     "It's not safe to use electrical appliances during a severe storm because lightning can travel through power lines."),
    ("How should you prepare your home if you live in a storm tide evacuation area?", 
     "If you live in a storm tide evacuation area, it's important to stay with friends or family who live in secure accommodation further inland and on higher ground."),
    ("What medical considerations should you have for cyclone or severe storm preparedness?", 
     "Consider any special medical needs, such as access to power, clean water (for dialysis), or oxygen, when preparing for cyclones and severe storms."),
    ("Where can you find information about the nearest cyclone shelters?", 
     "Your local council can provide information about the nearest cyclone shelters, and these shelters are often announced on local media."),
    ("What should you avoid doing immediately after a cyclone?", 
     "Immediately after a cyclone, you should avoid sightseeing, using damaged powerlines, and venturing into floodwaters."),
    ("What measures should be taken to ensure safe drinking water during a cyclone?", 
     "To ensure safe drinking water during a cyclone, use water purification tablets and avoid drinking potentially contaminated water."),
    ("How can you get assistance with obtaining necessary medication during an emergency?", 
     "For urgent assistance with getting necessary medication during an emergency, you can contact the State Emergency Services (SES) to arrange evacuation or an alternative supply."),
     ("Myth busted! – “But this property has never flooded before.”", 
     "Floods bigger than those we have experienced are inevitable. We have less than 200 years of formal flood records in Australia. While there may be no living memory or formal record of your property flooding, it does not mean that the land has not flooded in past centuries nor that it won't flood in coming years."),
    ("Myth busted! – “But I live on a hill so floods won’t affect me.”", 
     "Hills are not always free of floods. This can happen in two ways. 1. Creeks and rivers can rise several meters when they flood which means that land we think would be high and dry can end up being well under water. 2. When water is running down the hill to the creek or river it will find the easiest path to follow. Sometimes during a severe storm the pipes or kerb and guttering cannot handle all the water and the water will find its own path which could even be through properties on hills. Even if your property is not flooded, you may be isolated by floodwaters and you may not be able to leave or enter your property safely until floodwaters have subsided."),
    ("Myth busted! – “But I don’t even live near a creek or a river so floods won’t affect me.”", 
     "Water finds its way in unexpected places. This can happen in two ways. 1. When creeks and rivers burst their banks, the water can spread several hundred meters (even kilometers). 2. When water is running down the hill to the creek or river, it will find the easiest path to follow. Sometimes during a severe storm the pipes or kerb and guttering cannot handle all the water and the water will find its own path which could even be through properties on hills."),
    ("Myth busted! – “My home is above the flood level so floods won’t affect me.”", 
     "Floods can go higher than we plan for. In Australia, the flood planning level is usually defined by the 100-year flood. Floods can go higher than the 100-year flood level. This is not a flood which happens once every 100 years but one which has a 1 in 100 or 1% chance of occurring in each and every year. In a 70-year lifetime, there is a 50/50 chance of a 1 in 100 flood being exceeded at any location. Two such floods can occur one after the other. In 2007, rainfall exceeded the 1 in 100 event on the Sunshine Coast in Queensland, and again in 2011."),
    ("Myth busted! – “But I won’t even be here in 100 years ...so a 1 in 100 year flood won’t affect me.”", 
     "Extreme floods can happen at any time. In Australia, new buildings are usually built above the 100-year flood level. This is not a flood which happens once every 100 years but one which has a 1 in 100 or 1% chance of occurring in each and every year. In a 70-year lifetime, there is a 50/50 chance of a 1 in 100 flood being exceeded at any location. In fact, given the wet and dry phases that occur in many regions of Australia, these events are likely to be clustered in time."),
    ("Myth busted! – “We’re protected by levees where I live so flood won’t affect me.”", 
     "Levees can provide limited protection to buildings and infrastructure. It is not practical to build levees high enough to keep out all floods. Every levee has a chance of being overtopped by floodwaters and as such, communities should be prepared to evacuate to reduce the exposure to flood risks. When a levee overtops or fails, the water may rise very quickly in the areas which the levee was protecting. Many have been built by individuals privately and may not be properly maintained. Failures of levees occur regularly and can result in worse flooding in areas directly behind the failed levee than would occur naturally."),
    ("Myth busted! – “But I thought that dams were supposed to stop all flooding.”", 
     "Flood mitigation dams can reduce downstream flood levels by temporarily storing and later releasing floodwaters. Most dams are used to supply water to the community, but they can, when purpose-built, also provide some flood mitigation for events up to their flood storage capacity. However, in larger floods, this mitigation capacity can be exceeded, and floods pass through with little, if any, reduction. The effectiveness of dams depends on where in the catchment the rain falls. If it falls downstream of the dam, then the dam cannot mitigate flooding from that rainfall event. Dams can cause disruption to existing communities, loss of valuable land, and negative environmental impacts, and good sites for dams are difficult to locate. Detention basins act like dams but at a much smaller scale and are most suitable for 'green field' developments, where sizing constraints tend not to exist."),
    ("Myth busted! – “But I thought it would never flood during a drought.”", 
     "Flooding can happen at any time. Queensland has one of the most variable rainfalls in the world and experiences both regular and severe floods, and long droughts. In fact, significant flooding, and even record rainfall and flooding can occur in the middle of a drought without the drought breaking. For example, the 25 January-14 February 2019 flooding from the North and Far North Queensland Monsoon Trough saw over half of Queensland’s councils, covering more than 56% of Queensland’s land mass, activated for disaster funding assistance. Prior to the Monsoon Trough, more than half of Queensland was suffering prolonged drought, and following the Monsoon Trough, 67.4% of Queensland was drought declared."),
     ("Myth busted! – “But I thought that these sandbags would stop my home from flooding.”", 
     "Sandbags placed in appropriate locations around your home or business can reduce the impact of flooding. Sandbags will not stop the water completely, but can reduce the amount of water entering. Raising valuables off the floor may prevent damage to personal items from floodwater that may still enter."),
    ("Myth busted! – “I can drive through floodwaters – it won’t affect my car.”", 
     "It is dangerous and illegal to drive through floodwaters. Even shallow water can sweep a car off the road. In many cases, insurance does not cover water damage from driving through floodwaters."),
    ("Myth busted! – “But I can swim to safety in floodwaters.”", 
     "Attempting to swim in floodwaters is extremely dangerous. Swift currents, debris, and hidden hazards make it a life-threatening decision."),
    ("Myth busted! – “The flood won’t affect me because I can live off the land.”", 
     "Reliable access to food and clean water during floods can be limited. Flooding can disrupt transportation, contaminate water supplies, and make crops and livestock inaccessible. Relying on living off the land during a flood is not a safe or practical plan."),
    ("Myth busted! – “I don’t need flood insurance because the government will cover my losses.”", 
     "Flood insurance is not typically covered by standard homeowners' or renters' insurance. Government assistance may be available, but it is often in the form of low-interest loans that need to be repaid. Having flood insurance can provide more comprehensive coverage and financial protection."),
    ("Myth busted! – “I’ll evacuate when I see the water rising.”", 
     "Waiting until the water is rising to evacuate is dangerous. Floodwaters can rise rapidly and can trap you in your home. It's important to have an evacuation plan and follow local authorities' guidance on when to evacuate."),
    ("Myth busted! – “But I have a basement, so I'm safe from flooding.”", 
     "Basements are at risk of flooding, especially during heavy rainfall and flash floods. They can fill with water quickly, posing a danger to occupants and causing extensive damage to property."),
    ("Myth busted! – “My home is built to withstand floods, so I don't need to prepare.”", 
     "While some homes are designed to withstand floods, no building is entirely flood-proof. It's still important to prepare, have an evacuation plan, and protect your belongings in case of flooding."),
    ("Myth busted! – “My possessions are replaceable, so I'm not worried about flooding.”", 
     "While possessions can be replaced, flooding can lead to emotional distress, financial burdens, and loss of irreplaceable items like family heirlooms. It's essential to take steps to protect your belongings from flood damage."),
      ("Myth busted! – “I don’t need to prepare for floods; they won’t happen to me.”", 
     "Floods can happen to anyone, and it's essential to be prepared. Even areas that have not experienced flooding in many years can still be at risk, and preparation can make a significant difference in protecting your home and family."),
    ("Myth busted! – “But I don’t know how to swim, so I can’t be prepared for floods.”", 
     "Swimming is not a requirement for flood preparedness. Staying informed, having an emergency kit, evacuation plan, and knowing safe routes to higher ground are more important than swimming skills during a flood."),
    ("Myth busted! – “I don’t need an emergency kit; I can buy supplies during a flood.”", 
     "During a flood, stores may be inaccessible or out of supplies. Having an emergency kit with essential items like food, water, first aid, and medications is crucial to your safety and well-being."),
    ("Myth busted! – “I can use my phone's flashlight during a power outage.”", 
     "Relying solely on a phone's flashlight during a power outage can drain the battery quickly. It's a good idea to have additional battery-powered or hand-crank flashlights in your emergency kit."),
    ("Myth busted! – “But I don't have time to prepare for a flood; I'll do it later.”", 
     "Procrastinating flood preparedness can put you and your family at risk. It's important to prepare in advance, as floods can occur suddenly and without warning. Don't delay preparing your emergency kit and evacuation plan."),
    ("Myth busted! – “My pets will be fine on their own during a flood.”", 
     "Pets are vulnerable during floods. It's essential to include them in your emergency plans, with supplies and a safe place for them to stay. Leaving pets behind can put their lives at risk."),
    ("Myth busted! – “But I don't want to evacuate and leave my home during a flood.”", 
     "While it's natural to want to protect your home, staying during a flood can be extremely dangerous. Following evacuation orders from local authorities is crucial to ensure your safety."),
    ("Myth busted! – “I'll be able to call for help if needed during a flood.”", 
     "During a flood, communication infrastructure can be disrupted, and cell phone service may be unavailable. Having alternative communication methods like a battery-powered radio or satellite phone is important."),
    ("Myth busted! – “I can handle floodwaters on my own without assistance.”", 
     "Attempting to handle floodwaters alone can be risky. It's important to follow the guidance of local authorities, first responders, and emergency services for your safety during a flood."),
    ("Myth busted! – “Flood insurance is too expensive; I can't afford it.”", 
     "While flood insurance may have a cost, it can be a vital safeguard against significant financial losses during a flood. It's worth considering and evaluating your risk and insurance options."),
    ("Myth busted! – “I don’t need flood insurance because I rent my home.”", 
     "Flood insurance is typically associated with homeowners, but renters can also benefit from it. Tenant insurance, including flood coverage, can protect your belongings and provide peace of mind."),
    ("Myth busted! – “But I live in a low-risk flood area, so I don't need insurance.”", 
     "Flood risk can exist even in low-risk areas, and standard homeowners' insurance policies do not typically cover flood damage. It's a good idea to assess your risk and consider flood insurance."),
    ("Myth busted! – “My property is on elevated ground, so it won't flood.”", 
     "Elevation can reduce flood risk, but it does not guarantee immunity from flooding. Flooding can still occur due to various factors. Preparedness is essential regardless of your property's elevation."),
    ("Myth busted! – “But floodwaters won't damage my foundation; it's strong enough.”", 
     "Even strong foundations can be compromised by prolonged exposure to floodwaters. Water can weaken structures, leading to expensive repairs. Preventing flood damage is more cost-effective."),
    ("Myth busted! – “I can't prepare for floods because I have a disability or special needs.”", 
     "Preparation is crucial for everyone, including those with disabilities or special needs. Emergency plans should consider specific requirements and ensure access to necessary resources and assistance."),
    ("Myth busted! – “But I've never personally witnessed a major flood, so I don't need to prepare.”", 
     "Lack of personal experience does not eliminate the risk of flooding. Floods can be sudden and catastrophic. Preparedness is essential for everyone, regardless of prior experience."),
    ("Myth busted! – “My area's drainage system can handle any amount of rainwater.”", 
     "While drainage systems can manage some rainfall, extreme weather events can overwhelm them. Flooding can occur when water exceeds the system's capacity. Be prepared for such situations."),
    ("Myth busted! – “My car can handle driving through floodwaters; it's built for it.”", 
     "Driving through floodwaters is extremely risky, even in vehicles designed for off-road or water crossing. It's best to avoid flooded areas and find safer routes during a flood."),
    ("Myth busted! – “I don’t need to secure important documents during a flood; they'll be fine.”", 
     "Important documents are vulnerable to water damage during floods. It's wise to keep them in waterproof containers and take steps to safeguard your documents."),






]

# Create a DataFrame
df = pd.DataFrame(data, columns=["Question", "Answer"])
df
# Out:
#                                               Question  \
# 0     What is the purpose of having an Emergency Plan?
# 1    How should all household members be involved i...
# 2    Why is it important to practice your Emergency...
# 3    What are the four key steps to help create you...
# 4    How can you research hazards and disaster mana...
# ..                                                 ...
# 281  Myth busted! – “But I don't have time to prepa...
# 282  Myth busted! – “My pets will be fine on their ...
# 283  Myth busted! – “But I don't want to evacuate a...
# 284  Myth busted! – “I'll be able to call for help ...
# 285  Myth busted! – “I can handle floodwaters on my...
#
#                                                 Answer
# 0    Having an Emergency Plan is crucial for prepar...
# 1    All household members should be involved in di...
# 2    Practicing your Emergency Plan regularly is im...
# 3    The four key steps to create your Emergency Pl...
# ...

# %%
df.to_csv('faq2.csv', index=False)
