# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
available_datasets = gpd.datasets.available

# %%
print("Available Datasets:")
for dataset in available_datasets:
    print("- " + dataset)
# Out:
# Available Datasets:
# - naturalearth_cities
# - naturalearth_lowres
# - nybb

# %%
dataset_name = "naturalearth_lowres"
gdf = gpd.read_file(gpd.datasets.get_path(dataset_name))
# Out:
# C:\Users\bbsur\AppData\Local\Temp\ipykernel_14632\900629920.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gdf = gpd.read_file(gpd.datasets.get_path(dataset_name))

# %%
gdf.plot()
plt.show()

# %%
gdf.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
type(gdf.geometry[0])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
gdf.query('name == "India"').plot()
# Out:
# <Axes: >
