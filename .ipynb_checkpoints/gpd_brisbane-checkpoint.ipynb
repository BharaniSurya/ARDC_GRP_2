# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file("texas/20190919S1UCONN.shp")
gdf
# Out:
#       Parts    Length      Area  \
# 0         1  0.006648  0.000001
# 1         1  0.014014  0.000003
# 2        18  0.071147  0.000017
# 3        55  0.395438  0.000107
# 4         1  0.015990  0.000004
# ...     ...       ...       ...
# 7826      1  0.000359  0.000000
# 7827      1  0.001258  0.000000
# 7828      1  0.023716  0.000004
# 7829      1  0.000539  0.000000
# 7830      2  0.013115  0.000003
#
#                                                geometry
# 0     POLYGON ((-93.23168 30.93412, -93.23141 30.934...
# 1     POLYGON ((-93.13125 30.96808, -93.13098 30.968...
# 2     POLYGON ((-93.55804 30.91310, -93.55795 30.913...
# 3     POLYGON ((-93.54897 30.90025, -93.54888 30.900...
# 4     POLYGON ((-93.40533 30.89882, -93.40506 30.898...
# ...                                                 ...
# 7826  POLYGON ((-95.04457 29.14800, -95.04448 29.148...
# 7827  POLYGON ((-95.04439 29.14773, -95.04385 29.147...
# 7828  POLYGON ((-94.99463 29.18330, -94.99454 29.183...
# ...

# %%
gdf.plot()
plt.show()

# %%
gdf1 = gpd.read_file("texas/20190922MODIS.shp")
gdf1
# Out:
#      Parts    Length      Area  \
# 0        1  0.035184  0.000048
# 1        1  0.008796  0.000005
# 2        1  0.030786  0.000029
# 3        1  0.013194  0.000010
# 4        1  0.035184  0.000029
# ..     ...       ...       ...
# 538      1  0.008796  0.000005
# 539      1  0.021990  0.000019
# 540      1  0.008796  0.000005
# 541      1  0.008796  0.000005
# 542      1  0.013194  0.000010
#
#                                               geometry
# 0    POLYGON ((-94.34600 29.97544, -94.34380 29.975...
# 1    POLYGON ((-94.33060 29.97544, -94.32841 29.975...
# 2    POLYGON ((-94.50872 29.95125, -94.50213 29.951...
# 3    POLYGON ((-94.46914 29.92046, -94.46474 29.920...
# 4    POLYGON ((-94.33720 29.91606, -94.33280 29.916...
# ..                                                 ...
# 538  POLYGON ((-92.50542 29.56642, -92.50322 29.566...
# 539  POLYGON ((-92.48343 29.56202, -92.47463 29.562...
# 540  POLYGON ((-92.43945 29.55323, -92.43725 29.553...
# ...

# %%
gdf1.plot()
plt.show()

# %%
gdf2 = gpd.read_file("texas/201909190018UTCS1LIST.shp")
gdf2
# Out:
#       Parts   Length           Area  \
# 0         4   1520.0   17599.998535
# 1         1   2240.0   17600.001709
# 2        11   6880.0   92000.000244
# 3        37  14360.0  276399.995361
# 4         8   4920.0   66399.998779
# ...     ...      ...            ...
# 2890      1    960.0   25600.000244
# 2891      2   2240.0   33999.999634
# 2892      1   1640.0   17200.000244
# 2893      1   1400.0   16400.000244
# 2894      3   2520.0   33999.999756
#
#                                                geometry
# 0     POLYGON ((477619.930 3382052.923, 477639.930 3...
# 1     POLYGON ((502479.930 3385412.923, 502519.930 3...
# 2     POLYGON ((519699.930 3376552.923, 519719.930 3...
# 3     POLYGON ((519759.930 3375992.923, 519799.930 3...
# 4     POLYGON ((518919.930 3375952.923, 518939.930 3...
# ...                                                 ...
# 2890  POLYGON ((313219.930 3235772.923, 313259.930 3...
# 2891  POLYGON ((296959.930 3223732.923, 297079.930 3...
# ...

# %%
gdf2.plot()
plt.show()
