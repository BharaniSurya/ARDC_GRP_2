# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file("aus/2018013020180106S1Australia4567_region.shp")
gdf
# Out:
#       PARTS    LENGTH          AREA  \
# 0         1  0.003792  1.000000e-06
# 1         1  0.006500  1.000000e-06
# 2         1  0.005236  1.000000e-06
# 3         1  0.003792  1.000000e-06
# 4         1  0.007764  2.000000e-06
# ...     ...       ...           ...
# 2969      1  0.005236  1.000000e-06
# 2970      1  0.004514  1.000000e-06
# 2971      1  0.009209  1.000000e-06
# 2972      1  0.007222  1.000000e-06
# 2973      1  0.003611  1.000000e-06
#
#                                                geometry
# 0     POLYGON ((123.70853 -16.14428, 123.70907 -16.1...
# 1     POLYGON ((124.09149 -16.23059, 124.09158 -16.2...
# 2     POLYGON ((124.38445 -16.32024, 124.38490 -16.3...
# 3     POLYGON ((124.70567 -16.42207, 124.70612 -16.4...
# 4     POLYGON ((124.75027 -16.42947, 124.75063 -16.4...
# ...                                                 ...
# 2969  POLYGON ((124.72490 -17.95349, 124.72526 -17.9...
# 2970  POLYGON ((124.71966 -17.95376, 124.72002 -17.9...
# ...

# %%
gdf.plot()
plt.show()

# %%
gdf.plot(column='LENGTH', cmap='viridis', legend=True, legend_kwds={'label': "Length"}, markersize=50)
# Out:
# <Axes: >
